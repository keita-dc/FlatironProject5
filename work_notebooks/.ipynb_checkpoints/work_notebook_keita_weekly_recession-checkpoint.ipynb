# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import requests
import seaborn as sns

from dotenv import load_dotenv

# %matplotlib inline
plt.style.use("ggplot")
sns.set_context("talk")

# %%
load_dotenv("../")
FREDkey = os.getenv("FREDkey")
# Out:
# True

# %%
varlist = ["CPIAUCSL", 
           "T10Y2Y",
           "DGS10",
           "GS2",
           "GS5",
           "TB3MS",
           "IC4WSA",
           "MORTGAGE30US",
           "AAA",
           "BAA",
           "FEDFUNDS",
           "TWEXBMTH",
           "INDPRO",
           "IPMAN",
           "UMCSENT",
           "HOUST",
           "AHETPI",
           "CIVPART",
           "UNRATE",
           "PCE",
           "TCU",
           "USREC"]

# %%
datalist=[]
for var in varlist:
    resp = requests.get(
        "https://api.stlouisfed.org/fred/series/observations?series_id={}&api_key={}&file_type=json"
        .format(var, 
                FREDkey))
    df = pd.DataFrame(resp.json()['observations'])
    df.date = pd.to_datetime(df.date)
    df = df.loc[df.value!="."]
    df.value = df.value.astype(float)
    df.index = df.date
    df.drop(columns=["realtime_end", "realtime_start", "date"], axis=1, inplace=True)
    df.columns=[var]
    df= df.resample("1M").mean()
    datalist.append(df)

# %%
from functools import reduce
df_merged = reduce(lambda  left,　right: pd.merge(left,　right,　on='date',　how='outer'), datalist)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1977 entries, 1947-01-31 to 1918-12-31
# Data columns (total 22 columns):
# CPIAUCSL        870 non-null float64
# T10Y2Y          519 non-null float64
# DGS10           692 non-null float64
# GS2             518 non-null float64
# GS5             796 non-null float64
# TB3MS           1027 non-null float64
# IC4WSA          631 non-null float64
# MORTGAGE30US    581 non-null float64
# AAA             1207 non-null float64
# BAA             1207 non-null float64
# FEDFUNDS        781 non-null float64
# TWEXBMTH        559 non-null float64
# INDPRO          1206 non-null float64
# IPMAN           570 non-null float64
# UMCSENT         590 non-null float64
# HOUST           726 non-null float64
# AHETPI          667 non-null float64
# CIVPART         859 non-null float64
# UNRATE          859 non-null float64
# PCE             726 non-null float64
# TCU             630 non-null float64
# USREC           1976 non-null float64
# ...

# %%
df_merged.dropna(inplace=True)

# %%
y3 = df_merged.USREC.shift(-3)
y6 = df_merged.USREC.shift(-6)
y12 = df_merged.USREC.shift(-12)

# %%
percent = ["CPIAUCSL", 
           "IC4WSA",
           "TWEXBMTH",
           "INDPRO",
           "IPMAN",
           "HOUST",
           "AHETPI",
          "PCE"]

# %%
actual = ["T10Y2Y",
            "DGS10",
            "GS2",
            "GS5",
            "TB3MS",
            "MORTGAGE30US",
            "AAA",
            "BAA",
            "FEDFUNDS",
            "UMCSENT",  
            "CIVPART",
            "TCU",
            "UNRATE"]

# %%
def change(df, percent, actual, period):
    df_actual = df[actual].diff(period)

    df_percent = df[percent].pct_change(period)
    df_concat = pd.concat([df_actual, df_percent], axis=1)
    df_concat.columns = [str(col) + '_{}'.format(period) for col in df_concat.columns]
    return df_concat

# %%
one_m = change(df_merged, percent, actual, 1)
six_m = change(df_merged, percent, actual, 6)
one_y = change(df_merged, percent, actual, 12)

# %%
X = pd.concat([one_m, six_m, one_y], axis=1).dropna()

# %%
X
# Out:
#             T10Y2Y_1   DGS10_1  GS2_1  GS5_1  TB3MS_1  MORTGAGE30US_1  AAA_1  \
# date
# 1978-07-31 -0.072227  0.177727   0.25   0.18     0.28          0.0320   0.12
# 1978-08-31 -0.106152 -0.229130  -0.12  -0.21     0.07          0.0450  -0.19
# 1978-09-30 -0.193348  0.005630   0.20   0.10     0.77         -0.0290   0.00
# 1978-10-31 -0.062429  0.225881   0.28   0.18     0.14          0.1015   0.20
# 1978-11-30 -0.408071  0.162619   0.57   0.23     0.65          0.2500   0.14
# 1978-12-31 -0.089500  0.201500   0.30   0.24     0.44          0.2385   0.13
# 1979-01-31 -0.051455  0.093045   0.14   0.12     0.27          0.0440   0.09
# 1979-02-28  0.142121 -0.001212  -0.14  -0.07    -0.03          0.0175   0.01
# 1979-03-31 -0.053939  0.018939   0.07   0.07     0.16          0.0185   0.11
# 1979-04-30  0.075773  0.064727  -0.01   0.05    -0.02          0.0715   0.01
# 1979-05-31  0.065071  0.070381   0.00  -0.01     0.15          0.1925   0.12
# ...

# %%
y3 = y3[X.index].dropna()
y6 = y6[X.index].dropna()
y12 = y12[X.index].dropna()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X))

# %%
from sklearn.model_selection import train_test_split
X3_train, X3_test, y3_train, y3_test = train_test_split(X_scaled[:len(y3)], y3, stratify=y3)
X6_train, X6_test, y6_train, y6_test = train_test_split(X_scaled[:len(y6)], y6, stratify=y6)
X12_train, X12_test, y12_train, y12_test = train_test_split(X_scaled[:len(y12)], y12, stratify=y12)

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

clf = SVC(C=10, gamma=0.01, probability=True)
clf.fit(X3_train, y3_train)
confusion_matrix(clf.predict(X3_test), y3_test)
# Out:
# array([[108,   2],
#        [  1,  12]])

# %%
from sklearn.model_selection import GridSearchCV
clf = SVC()
param_grid = {"C" : np.linspace(.1, 20, num=11),
             "gamma" : np.linspace(10**-4, 5, num=6)}
grid_search = GridSearchCV(clf, param_grid, cv=5, scoring="average_precision")
# %timeit grid_search.fit(X3_train, y3_train)
# Out:
# 5.6 s ± 437 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
grid_search.best_params_
# Out:
# {'C': 20.0, 'gamma': 0.0001}

# %%
clf.score(X3_train, y3_train)
# Out:
# 0.9972677595628415

# %%
clf.score(X3_test, y3_test)
# Out:
# 0.975609756097561

# %%
clf.predict_proba(X_scaled)[:, 1].shape
# Out:
# (492,)

# %%
pred3 = pd.DataFrame(clf.predict_proba(X_scaled)[:, 1])
pred3.set_index(X.index, inplace=True)
pred3.columns = ["3m_pred"]

# %%
fig = plt.figure(figsize=(16,4))
ax = plt.plot(pd.merge(df_merged.USREC[X_scaled.index], pred3, on="date"))
plt.title("US 3M Forward Recession Forecast")
plt.ylabel("Probability")
plt.legend(["NBER Recession", "Prediction"])
plt.savefig("../images/3m_svc")
plt.show()

# %%
from sklearn.svm import SVC
clf = SVC(C=10, gamma=0.001, probability=True)
clf.fit(X6_train, y6_train)

confusion_matrix(clf.predict(X6_test), y6_test)
# Out:
# array([[100,   3],
#        [  8,  11]])

# %%
from sklearn.model_selection import GridSearchCV
clf = SVC()
param_grid = {"C" : np.linspace(.1, 20, num=11),
             "gamma" : np.linspace(10**-4, 5, num=6)}
grid_search = GridSearchCV(clf, param_grid, cv=5, scoring="f1")
# %timeit grid_search.fit(X6_train, y6_train)
# Out:
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmiyaki/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
grid_search.best_params_
# Out:
# {'C': 20.0, 'gamma': 0.0001}

# %%
clf.score(X6_train, y6_train)
# Out:
# 0.945054945054945

# %%
clf.score(X6_test, y6_test)
# Out:
# 0.9098360655737705

# %%
clf.predict_proba(X_scaled)[:, 1].shape
# Out:
# (492,)

# %%
pred6 = pd.DataFrame(clf.predict_proba(X_scaled)[:, 1])
pred6.set_index(X.index, inplace=True)
pred6.columns = ["6m_pred"]

# %%
fig = plt.figure(figsize=(16,4))
ax = plt.plot(pd.merge(df_merged.USREC[X_scaled.index], pred6, on="date"))
plt.title("US 6M Forward Recession Forecast")
plt.ylabel("Probability")
plt.legend(["NBER Recession", "Prediction"])
plt.savefig("../images/6m_svc")
plt.show()

# %%
from sklearn.svm import SVC
clf = SVC(C=16, gamma=0.008, probability=True)
clf.fit(X12_train, y12_train)
confusion_matrix(clf.predict(X12_test), y12_test)
# Out:
# array([[101,   6],
#        [  5,   8]])

# %%
# from sklearn.model_selection import GridSearchCV
# clf = SVC()
# param_grid = {"C" : np.linspace(.1, 20, num=11),
#              "gamma" : np.linspace(10**-3, 5, num=5)}
# grid_search = GridSearchCV(clf, param_grid, cv=5)
# %timeit grid_search.fit(X12_train, y12_train)
# Out:
# 3.64 s ± 27.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# grid_search.best_params_
# Out:
# {'C': 18.009999999999998, 'gamma': 0.001}

# %%
clf.score(X12_train, y12_train)
# Out:
# 0.9944444444444445

# %%
clf.score(X12_test, y12_test)
# Out:
# 0.9083333333333333

# %%
clf.predict_proba(X_scaled)[:, 1].shape
# Out:
# (492,)

# %%
pred12 = pd.DataFrame(clf.predict_proba(X_scaled)[:, 1])
pred12.set_index(X.index, inplace=True)
pred12.columns = ["12m_pred"]

# %%
fig = plt.figure(figsize=(16,4))
ax = plt.plot(pd.merge(df_merged.USREC[X_scaled.index], pred12, on="date"))
plt.title("US 12M Forward Recession Forecast")
plt.ylabel("Probability")
plt.legend(["NBER Recession", "Prediction"])
plt.savefig("../images/12m_svc")
plt.show()
